# %% [markdown]
# # Text Preprocessing
# #### Pandas
# #### NLTK

# %%
import nltk

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import word_tokenize, sent_tokenize


text = """Practicing text tokenization with NLTK, a popular Python library for
 natural language processing. Let's Rock!"""

words = word_tokenize(text)

sentences = sent_tokenize(text)

print(words)
print(sentences)
# Out:
# ['Practicing', 'text', 'tokenization', 'with', 'NLTK', ',', 'a', 'popular', 'Python', 'library', 'for', 'natural', 'language', 'processing', '.', 'Let', "'s", 'Rock', '!']
# ['Practicing text tokenization with NLTK, a popular Python library for\n natural language processing.', "Let's Rock!"]

# %% [markdown]
# Stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords

# %%
stop_words = set(stopwords.words('english'))

# %%
words = word_tokenize(text)
filterStopWords = [word for word in ]
